# %%
import pandas as pd

# %%
df = pd.read_csv('EADA_2019_filtered_coord.csv')
df
# Out:
#       unitid                     institution_name               addr1_txt  \
# 0     100654             Alabama A & M University    4900 Meridian Street
# 1     100706  University of Alabama in Huntsville         301 Sparkman Dr
# 2     100724             Alabama State University    915 S Jackson Street
# 3     100751            The University of Alabama     739 University Blvd
# 4     100760    Central Alabama Community College        1675 Cherokee Rd
# ...      ...                                  ...                     ...
# 1807  486901                     Milligan College         1 Blowers Blvd.
# 1808  487524                    Husson University        1 College Circle
# 1809  488785        University of Saint Katherine      1637 Capalina Road
# 1810  489937    Piedmont International University        420 S. Broad St.
# 1811  800001              Simon Fraser University  8888 University Drive,
#
#                          addr2_txt          city_txt state_cd  zip_text  \
# ...

# %%
for index, row in df.iterrows():
    if row['institution_name'] in ['Columbia Basin College', 'Heidelberg University', 'Manchester University']:
        df.drop(index = index, inplace = True)
        
df
# Out:
#       unitid                     institution_name               addr1_txt  \
# 0     100654             Alabama A & M University    4900 Meridian Street
# 1     100706  University of Alabama in Huntsville         301 Sparkman Dr
# 2     100724             Alabama State University    915 S Jackson Street
# 3     100751            The University of Alabama     739 University Blvd
# 4     100760    Central Alabama Community College        1675 Cherokee Rd
# ...      ...                                  ...                     ...
# 1807  486901                     Milligan College         1 Blowers Blvd.
# 1808  487524                    Husson University        1 College Circle
# 1809  488785        University of Saint Katherine      1637 Capalina Road
# 1810  489937    Piedmont International University        420 S. Broad St.
# 1811  800001              Simon Fraser University  8888 University Drive,
#
#                          addr2_txt          city_txt state_cd  zip_text  \
# ...

# %%
df.to_csv('EADA_2019_filtered_coord.csv', index = False)
